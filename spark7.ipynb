# %%
# !pip install pyspark

from pyspark.sql import SparkSession
from pyspark.sql import Row
import collections
# Out:
# Requirement already satisfied: pyspark in /usr/local/lib/python3.12/dist-packages (4.0.1)
# Requirement already satisfied: py4j==0.10.9.9 in /usr/local/lib/python3.12/dist-packages (from pyspark) (0.10.9.9)

# %%
with open("movies.dat", encoding="ISO-8859-1") as f:
  for line in f:
    print(line.strip())
# Out:
# 1::Movie 1 (2001)::Action
# 2::Movie 2 (2002)::Action
# 3::Movie 3 (2003)::Romance
# 4::Movie 4 (2004)::Drama
# 5::Movie 5 (2005)::Drama
# 6::Movie 6 (2006)::Thriller
# 7::Movie 7 (2007)::Comedy
# 8::Movie 8 (2008)::Comedy
# 9::Movie 9 (2009)::Sci-Fi
# 10::Movie 10 (2000)::Thriller
# 11::Movie 11 (2001)::Sci-Fi
# 12::Movie 12 (2002)::Comedy
# 13::Movie 13 (2003)::Sci-Fi
# 14::Movie 14 (2004)::Action
# 15::Movie 15 (2005)::Comedy
# 16::Movie 16 (2006)::Comedy
# 17::Movie 17 (2007)::Action
# 18::Movie 18 (2008)::Comedy
# 19::Movie 19 (2009)::Action
# 20::Movie 20 (2000)::Sci-Fi
# 21::Movie 21 (2001)::Thriller
# 22::Movie 22 (2002)::Sci-Fi
# 23::Movie 23 (2003)::Thriller
# 24::Movie 24 (2004)::Sci-Fi
# 25::Movie 25 (2005)::Sci-Fi
# 26::Movie 26 (2006)::Romance
# 27::Movie 27 (2007)::Drama
# 28::Movie 28 (2008)::Romance
# 29::Movie 29 (2009)::Thriller
# 30::Movie 30 (2000)::Drama
# 31::Movie 31 (2001)::Drama
# 32::Movie 32 (2002)::Sci-Fi
# 33::Movie 33 (2003)::Comedy
# 34::Movie 34 (2004)::Thriller
# 35::Movie 35 (2005)::Drama
# 36::Movie 36 (2006)::Thriller
# 37::Movie 37 (2007)::Thriller
# 38::Movie 38 (2008)::Comedy
# 39::Movie 39 (2009)::Sci-Fi
# 40::Movie 40 (2000)::Thriller
# 41::Movie 41 (2001)::Romance
# 42::Movie 42 (2002)::Action
# 43::Movie 43 (2003)::Drama
# 44::Movie 44 (2004)::Romance
# 45::Movie 45 (2005)::Action
# 46::Movie 46 (2006)::Thriller
# 47::Movie 47 (2007)::Romance
# 48::Movie 48 (2008)::Comedy
# 49::Movie 49 (2009)::Sci-Fi
# 50::Movie 50 (2000)::Thriller
# 51::Movie 51 (2001)::Thriller
# 52::Movie 52 (2002)::Comedy
# 53::Movie 53 (2003)::Romance
# 54::Movie 54 (2004)::Comedy
# 55::Movie 55 (2005)::Sci-Fi
# 56::Movie 56 (2006)::Thriller
# 57::Movie 57 (2007)::Drama
# 58::Movie 58 (2008)::Romance
# 59::Movie 59 (2009)::Action
# 60::Movie 60 (2000)::Drama
# 61::Movie 61 (2001)::Comedy
# 62::Movie 62 (2002)::Drama
# 63::Movie 63 (2003)::Sci-Fi
# 64::Movie 64 (2004)::Comedy
# 65::Movie 65 (2005)::Drama
# 66::Movie 66 (2006)::Thriller
# 67::Movie 67 (2007)::Thriller
# 68::Movie 68 (2008)::Thriller
# 69::Movie 69 (2009)::Comedy
# 70::Movie 70 (2000)::Drama
# 71::Movie 71 (2001)::Thriller
# 72::Movie 72 (2002)::Thriller
# 73::Movie 73 (2003)::Drama
# 74::Movie 74 (2004)::Action
# 75::Movie 75 (2005)::Drama
# 76::Movie 76 (2006)::Drama
# 77::Movie 77 (2007)::Sci-Fi
# 78::Movie 78 (2008)::Comedy
# 79::Movie 79 (2009)::Comedy
# 80::Movie 80 (2000)::Romance
# 81::Movie 81 (2001)::Sci-Fi
# 82::Movie 82 (2002)::Action
# 83::Movie 83 (2003)::Romance
# 84::Movie 84 (2004)::Drama
# 85::Movie 85 (2005)::Action
# 86::Movie 86 (2006)::Action
# 87::Movie 87 (2007)::Comedy
# 88::Movie 88 (2008)::Romance
# 89::Movie 89 (2009)::Drama
# 90::Movie 90 (2000)::Drama
# 91::Movie 91 (2001)::Action
# 92::Movie 92 (2002)::Drama
# 93::Movie 93 (2003)::Romance
# 94::Movie 94 (2004)::Romance
# 95::Movie 95 (2005)::Romance
# 96::Movie 96 (2006)::Sci-Fi
# 97::Movie 97 (2007)::Thriller
# 98::Movie 98 (2008)::Comedy
# 99::Movie 99 (2009)::Sci-Fi
# 100::Movie 100 (2000)::Drama

# %%
with open("ratings.dat") as f:
  for line in f:
    print(line.strip())
# Out:
# 6::36::5::1131283453
# 14::42::2::1467785159
# 22::30::4::1155486604
# 11::83::1::1196651871
# 20::91::3::1225595582
# 17::62::1::1315983126
# 28::85::1::1038001970
# 15::20::1::1356307144
# 13::87::2::1235367254
# 26::78::5::1053997241
# 23::95::2::1152275754
# 10::87::5::1114159216
# 15::100::3::1330050989
# 7::41::2::1456277037
# 28::21::1::1461972621
# 27::11::1::1426963347
# 15::38::5::1114132855
# 4::40::5::1300272852
# 4::78::2::1050320375
# 2::51::2::1270291967
# 18::1::4::1301663549
# 13::89::5::1204800860
# 25::58::3::1156153431
# 3::41::4::1100611986
# 1::28::5::1195339058
# 29::25::3::1371078711
# 6::55::3::1368162769
# 7::74::4::1063981795
# 27::36::4::1227795889
# 7::46::1::1163463566
# 6::15::2::1243084148
# 3::53::2::1129081451
# 3::47::5::1444649600
# 14::46::4::1209273991
# 7::12::4::1241725768
# 25::8::3::1181016630
# 15::81::4::1392406578
# 14::25::4::1300761211
# 19::75::5::1364232418
# 17::61::4::1454560905
# 22::18::2::1403143400
# 24::50::4::1388957954
# 9::65::2::1108637428
# 14::22::4::1498050940
# 9::53::1::1358251615
# 21::60::2::1069562658
# 18::13::3::1038509510
# 2::14::3::1058509849
# 26::9::1::1112475180
# 28::15::3::1046120690
# 16::85::5::1221564968
# 16::42::3::1383706668
# 18::47::2::1354596983
# 10::4::5::1089670134
# 18::99::1::1474246871
# 13::78::5::1172652739
# 29::97::2::1285364074
# 14::20::5::1091450307
# 29::7::4::1348742075
# 21::89::5::1290686621
# 6::38::3::1090629607
# 21::90::1::1343421815
# 5::16::5::1209135513
# 12::15::3::1383351256
# 28::28::2::1350606028
# 24::48::3::1330596072
# 1::64::2::1277352615
# 30::87::4::1447233382
# 16::34::4::1145135605
# 16::7::2::1139365432
# 9::25::5::1490114609
# 29::61::1::1277452183
# 26::96::1::1450717982
# 26::19::2::1001028024
# 4::80::2::1488470952
# 18::19::2::1284029002
# 23::20::5::1434697949
# 19::44::1::1067079155
# 20::72::3::1376440771
# 8::64::2::1062053273
# 16::34::2::1399982583
# 8::96::3::1088287921
# 20::66::3::1482103298
# 1::86::4::1113364763
# 25::57::4::1420598092
# 1::37::3::1016305522
# 22::3::1::1095604876
# 16::51::3::1260437072
# 7::97::1::1365154899
# 10::97::3::1153329618
# 26::42::5::1045715477
# 4::33::1::1253955787
# 25::66::1::1387976018
# 5::23::3::1296666728
# 5::54::1::1336133438
# 26::98::5::1197412550
# 19::80::4::1258696250
# 4::31::5::1452909693
# 16::44::3::1236883780
# 17::29::1::1374749158

# %%
from pyspark.sql import SparkSession

# %%
# Start Spark
spark = SparkSession.builder.appName("BroadcastMovieNames").getOrCreate()
sc = spark.sparkContext

# %%
# ==========================
# Load Movie Names Function
# ==========================
def loadMovieNames():
    movieNames = {}
    with open("movies.dat", encoding="ISO-8859-1") as f:
        for line in f:
            fields = line.strip().split("::")
            if len(fields) >= 2:
                movieId = int(fields[0])
                movieName = fields[1]
                movieNames[movieId] = movieName
    return movieNames

# %%
# Broadcast movie names
movieNamesDict = loadMovieNames()
movieNamesBroadcast = sc.broadcast(movieNamesDict)

# %%
# ==========================
# Load Ratings Dataset
# ==========================
ratings = sc.textFile("ratings.dat")

ratingsParsed = ratings.map(lambda l: l.split("::")) \
                       .map(lambda f: (int(f[0]), int(f[1]), float(f[2])))

# %%
# ==========================
# Replace movieId with Names
# ==========================
ratingsWithNames = ratingsParsed.map(
    lambda x: (x[0], movieNamesBroadcast.value.get(x[1], "Unknown"), x[2])
)

# Show sample results
for result in ratingsWithNames.take(10):
    print(result)

# Stop Spark
spark.stop()
# Out:
# (6, 'Movie 36 (2006)', 5.0)
# (14, 'Movie 42 (2002)', 2.0)
# (22, 'Movie 30 (2000)', 4.0)
# (11, 'Movie 83 (2003)', 1.0)
# (20, 'Movie 91 (2001)', 3.0)
# (17, 'Movie 62 (2002)', 1.0)
# (28, 'Movie 85 (2005)', 1.0)
# (15, 'Movie 20 (2000)', 1.0)
# (13, 'Movie 87 (2007)', 2.0)
# (26, 'Movie 78 (2008)', 5.0)
