# %%
# !PIP INSTALL PYSPARK
# Out:
# /bin/bash: line 1: PIP: command not found

# %%
import os
# !apt-get update -qq > /dev/null
# !apt-get install -y openjdk-8-jdk-headless -qq > /dev/null
os.environ["JAVA_HOME"] = "/usr/lib/jvm/java-8-openjdk-amd64"
# Out:
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)

# %%
input = sc.textFile("text.txt")  # here input is rdd
words = input.flatMap(lambda x: x.split())   #all word count present here.
wordcounts = words.countByValue()   #har unique word ka count banata hai  value give key : pair

for word,count  in wordcounts.items(): #Har word aur uska count lo, ek-ek karke.
  cleanword = word.encode('ascii','ignore') #Word ko ASCII format me convert karo
                                             # Non-ASCII characters hata do (ignore)
  if(cleanword):                             #Agar cleanword empty nahi hai → print karo
     print(cleanword.decode()+ " " + str(count)) # cleanword and count ko srt may convert
                                                  # kar phir print karo
# Out:
# I 2
# am 2
# student 2
# of 3
# computer 2
# stream 1
# science 2
# and 1
# main 1
# program 1
# data 1
